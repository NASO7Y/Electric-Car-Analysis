# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
ev = pd.read_csv("D:\ElectricCarData.csv")
ev.head(8)
# Out:
#          Brand                          Model  Accel  TopSpeed  Range  \
# 0       Tesla   Model 3 Long Range Dual Motor    4.6       233    450
# 1  Volkswagen                       ID.3 Pure   10.0       160    270
# 2    Polestar                               2    4.7       210    400
# 3         BMW                            iX3     6.8       180    360
# 4       Honda                              e     9.5       145    170
# 5       Lucid                            Air     2.8       250    610
# 6  Volkswagen                         e-Golf     9.6       150    190
# 7     Peugeot                          e-208     8.1       150    275
#
#    Efficiency  FastCharge         PowerTrain    PlugType  BodyStyle  Seats  \
# 0         161         940    All Wheel Drive  Type 2 CCS      Sedan      5
# 1         167         250   Rear Wheel Drive  Type 2 CCS  Hatchback      5
# 2         181         620    All Wheel Drive  Type 2 CCS   Liftback      5
# 3         206         560   Rear Wheel Drive  Type 2 CCS        SUV      5
# 4         168         190   Rear Wheel Drive  Type 2 CCS  Hatchback      4
# 5         180         620    All Wheel Drive  Type 2 CCS      Sedan      5
# 6         168         220  Front Wheel Drive  Type 2 CCS  Hatchback      5
# 7         164         420  Front Wheel Drive  Type 2 CCS  Hatchback      5
#
#    PriceEuro
# 0      55480
# 1      30000
# 2      56440
# 3      68040
# 4      32997
# 5     105000
# 6      31900
# 7      29682

# %%
ev = pd.read_csv("D:\ElectricCarData.csv")
ev_tesla= ev[ev['Brand']=='Tesla ']
print(ev_tesla.reset_index())
# Out:
#     index   Brand                           Model  Accel  TopSpeed  Range  \
# 0       0  Tesla    Model 3 Long Range Dual Motor    4.6       233    450
# 1       8  Tesla      Model 3 Standard Range Plus    5.6       225    310
# 2      21  Tesla    Model Y Long Range Dual Motor    5.1       217    425
# 3      24  Tesla   Model 3 Long Range Performance    3.4       261    435
# 4      33  Tesla             Cybertruck Tri Motor    3.0       210    750
# 5      40  Tesla               Model S Long Range    3.8       250    515
# 6      51  Tesla                        Roadster     2.1       410    970
# 7      54  Tesla               Model X Long Range    4.6       250    450
# 8      59  Tesla              Model S Performance    2.5       261    505
# 9      61  Tesla   Model Y Long Range Performance    3.7       241    410
# 10     67  Tesla            Cybertruck Dual Motor    5.0       190    460
# 11     81  Tesla              Model X Performance    2.8       250    440
# 12     86  Tesla          Cybertruck Single Motor    7.0       180    390
#
#     Efficiency  FastCharge        PowerTrain    PlugType BodyStyle  Seats  \
# 0          161         940   All Wheel Drive  Type 2 CCS     Sedan      5
# 1          153         650  Rear Wheel Drive  Type 2 CCS     Sedan      5
# 2          171         930   All Wheel Drive  Type 2 CCS       SUV      7
# 3          167         910   All Wheel Drive  Type 2 CCS     Sedan      5
# 4          267         710   All Wheel Drive  Type 2 CCS    Pickup      6
# 5          184         560   All Wheel Drive      Type 2  Liftback      5
# 6          206         920   All Wheel Drive  Type 2 CCS    Cabrio      4
# 7          211         490   All Wheel Drive      Type 2       SUV      7
# 8          188         550   All Wheel Drive      Type 2  Liftback      5
# 9          177         900   All Wheel Drive  Type 2 CCS       SUV      7
# 10         261         710   All Wheel Drive  Type 2 CCS    Pickup      6
# 11         216         480   All Wheel Drive      Type 2       SUV      7
# 12         256         740  Rear Wheel Drive  Type 2 CCS    Pickup      6
#
#     PriceEuro
# 0       55480
# 1       46380
# 2       58620
# 3       61480
# 4       75000
# 5       79990
# 6      215000
# 7       85990
# 8       96990
# 9       65620
# 10      55000
# 11     102990
# 12      45000

# %%
print(ev.info())
print(" ---------------------------------")
print(ev.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Brand       103 non-null    object
#  1   Model       103 non-null    object
#  2   Accel       103 non-null    float64
#  3   TopSpeed    103 non-null    int64
#  4   Range       103 non-null    int64
#  5   Efficiency  103 non-null    int64
#  6   FastCharge  103 non-null    int64
#  7   PowerTrain  103 non-null    object
#  8   PlugType    103 non-null    object
#  9   BodyStyle   103 non-null    object
#  10  Seats       103 non-null    int64
#  11  PriceEuro   103 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 9.8+ KB
# None
#  ---------------------------------
# Brand         0
# Model         0
# Accel         0
# TopSpeed      0
# Range         0
# Efficiency    0
# FastCharge    0
# PowerTrain    0
# PlugType      0
# BodyStyle     0
# Seats         0
# PriceEuro     0
# dtype: int64

# %%
print(ev.describe())
print("___________________________________________________________")
# Out:
#             Accel    TopSpeed       Range  Efficiency  FastCharge       Seats  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     7.396117  179.194175  338.786408  189.165049  455.339806    4.883495
# std      3.017430   43.573030  126.014444   29.566839  196.861729    0.795834
# min      2.100000  123.000000   95.000000  104.000000  170.000000    2.000000
# 25%      5.100000  150.000000  250.000000  168.000000  305.000000    5.000000
# 50%      7.300000  160.000000  340.000000  180.000000  440.000000    5.000000
# 75%      9.000000  200.000000  400.000000  203.000000  555.000000    5.000000
# max     22.400000  410.000000  970.000000  273.000000  940.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000
# ___________________________________________________________

# %%
plot_Accel= ev["PriceEuro"]

plot_price= ev["Accel"]
plt.plot(plot_price,plot_Accel,linestyle=" ",marker="*")
plt.show()

# %%
ev["Top"] = ev["FastCharge"]/ev["TopSpeed"] #The battery runs out in (hours)

# %%
ev.sort_values(["Top"],ascending=False)
# Out:
#           Brand                          Model  Accel  TopSpeed  Range  \
# 21       Tesla   Model Y Long Range Dual Motor    5.1       217    425
# 91       Smart                EQ fortwo cabrio   11.9       130     95
# 86       Tesla         Cybertruck Single Motor    7.0       180    390
# 0        Tesla   Model 3 Long Range Dual Motor    4.6       233    450
# 67       Tesla           Cybertruck Dual Motor    5.0       190    460
# ..          ...                            ...    ...       ...    ...
# 17  Volkswagen                          e-Up!    11.9       130    195
# 43       Skoda                     CITIGOe iV    12.3       130    195
# 44        SEAT                   Mii Electric    12.3       130    195
# 14     Hyundai                  IONIQ Electric    9.7       165    250
# 36       Lexus                         UX 300e    7.5       160    270
#
#     Efficiency  FastCharge         PowerTrain        PlugType  BodyStyle  \
# 21         171         930    All Wheel Drive      Type 2 CCS        SUV
# 91         176         540   Rear Wheel Drive          Type 2     Cabrio
# 86         256         740   Rear Wheel Drive      Type 2 CCS     Pickup
# 0          161         940    All Wheel Drive      Type 2 CCS      Sedan
# 67         261         710    All Wheel Drive      Type 2 CCS     Pickup
# ..         ...         ...                ...             ...        ...
# 17         166         170  Front Wheel Drive      Type 2 CCS  Hatchback
# 43         166         170  Front Wheel Drive      Type 2 CCS  Hatchback
# 44         166         170  Front Wheel Drive      Type 2 CCS  Hatchback
# 14         153         210  Front Wheel Drive      Type 2 CCS   Liftback
# 36         193         190  Front Wheel Drive  Type 2 CHAdeMO        SUV
#
#     Seats  PriceEuro       Top
# 21      7      58620  4.285714
# 91      2      24565  4.153846
# 86      6      45000  4.111111
# 0       5      55480  4.034335
# 67      6      55000  3.736842
# ..    ...        ...       ...
# 17      4      21421  1.307692
# 43      4      24534  1.307692
# 44      4      20129  1.307692
# 14      5      34459  1.272727
# 36      5      50000  1.187500
#
# [103 rows x 13 columns]

# %%
plot_eff = ev["Efficiency"]

plot_Top = ev["Top"]
plt.plot(plot_eff,plot_Top,linestyle=" ",marker=".")
plt.show()

# %%
ev["BodyStyle"].unique()
# Out:
# array(['Sedan', 'Hatchback', 'Liftback', 'SUV', 'Pickup', 'MPV', 'Cabrio',
#        'SPV', 'Station'], dtype=object)

# %%
import csv
from collections import Counter
style_counter=Counter()
model_counter=Counter()
wheel_counter=Counter()

with open("D:\ElectricCarData.csv") as csv_file:
    csv_reader=csv.DictReader(csv_file)
    
    for row in csv_reader:
        style_counter.update(row["BodyStyle"].split(" "))
        model_counter.update(row["Brand"].split(" "))
        wheel_counter.update(row["PowerTrain"].split("Drive"))

style_counter
model_counter
wheel_counter
# Out:
# Counter({'All Wheel ': 41, '': 103, 'Rear Wheel ': 25, 'Front Wheel ': 37})

# %%
style_counter.most_common(5)
# Out:
# [('SUV', 45), ('Hatchback', 32), ('Sedan', 10), ('Liftback', 5), ('Pickup', 3)]

# %%
stylee=[]
frequency=[]
for item in style_counter.most_common(15):
        stylee.append(item[0]) 
        frequency.append(item[1])
print(stylee)
print(frequency)
# Out:
# ['SUV', 'Hatchback', 'Sedan', 'Liftback', 'Pickup', 'Cabrio', 'SPV', 'MPV', 'Station']
# [45, 32, 10, 5, 3, 3, 3, 1, 1]

# %%
plt.style.use("dark_background")
plt.barh(stylee,frequency,color="b")
plt.title("Most popular body style")
plt.ylabel("body style")
plt.xlabel("frequency")
plt.show()

# %%
stylee.reverse()
frequency.reverse()
plt.barh(stylee,frequency,color="c")
# Out:
# <BarContainer object of 9 artists>

# %%
model_counter[""]=0
model_counter
model_counter.most_common(10)
# Out:
# [('Tesla', 13),
#  ('Audi', 9),
#  ('Volkswagen', 8),
#  ('Nissan', 8),
#  ('Skoda', 6),
#  ('Porsche', 5),
#  ('Kia', 5),
#  ('Renault', 5),
#  ('BMW', 4),
#  ('Ford', 4)]

# %%
plt.style.use('Solarize_Light2')
plt.barh(model,frequencyy,color="k")
plt.title("Most popular Brand")
plt.ylabel("model")
plt.xlabel("frequency")
plt.show()

# %%
wheel=[]
frequenccy=[]
for item in wheel_counter.most_common(15):
        wheel.append(item[0]) 
        frequenccy.append(item[1])
del frequenccy[0]
del wheel[0]
print(wheel)
print(frequenccy)
# Out:
# ['All Wheel ', 'Front Wheel ', 'Rear Wheel ']
# [41, 37, 25]

# %%
plt.plot(wheel,frequenccy, color="k", linestyle="--", marker=" ", linewidth=2, label="Python Developers")

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')
plt.legend()
plt.grid(True)
plt.show()
